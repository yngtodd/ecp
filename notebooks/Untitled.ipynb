# %%
from hyperspace.kepler import load_results
from hyperspace.kepler.plots import plot_convergence

import matplotlib
import matplotlib.pyplot as plt
plt.style.use(['seaborn-ticks'])

# %matplotlib inline

# %%
def objective():
    pass


summitdev = '/Users/youngtodd/ecp/summitdev/space5/results'
results = load_results(summitdev)

best = results.pop(0)

# %%
matplotlib.rcParams['figure.figsize'] = [15, 15]
fig, _ = plot_convergence(best, results)

# %%
top10 = [results[x] for x in range(10)]
one, two, three, four, five, six, seven, eight, nine, ten = top10

matplotlib.rcParams['figure.figsize'] = [15, 15]
fig, _ = plot_convergence(best, one, two, three, four, five, six, seven, eight, nine, ten, yscale='log')

# %%
best.x_iters
# Out:
# [[8, 9, 9, 453, 0.07647508377601836],
#  [7, 6, 5, 275, 0.06735733442560111],
#  [9, 7, 7, 449, 0.05859140130007667],
#  [8, 7, 10, 234, 0.09188126560203755],
#  [7, 9, 8, 401, 0.08254128696627777],
#  [8, 8, 9, 224, 0.06710331620654518],
#  [6, 9, 6, 233, 0.05776303710577718],
#  [6, 6, 7, 470, 0.06562531218201478],
#  [8, 10, 5, 491, 0.07832342011214738],
#  [6, 7, 9, 379, 0.05781967026784073],
#  [9, 8, 9, 212, 0.05554609820369323]]

# %%
one.x_iters
# Out:
# [[4, 9, 9, 453, 0.07647508377601836],
#  [3, 6, 5, 275, 0.06735733442560111],
#  [5, 7, 7, 449, 0.05859140130007667],
#  [4, 7, 10, 234, 0.09188126560203755],
#  [3, 9, 8, 401, 0.08254128696627777],
#  [4, 8, 9, 224, 0.06710331620654518],
#  [2, 9, 6, 233, 0.05776303710577718],
#  [2, 6, 7, 470, 0.06562531218201478],
#  [4, 10, 5, 491, 0.07832342011214738],
#  [2, 7, 9, 379, 0.05781967026784073],
#  [5, 8, 9, 212, 0.056105541758290634]]

# %%
two.x_iters
# Out:
# [[8, 5, 9, 453, 0.07647508377601836],
#  [7, 2, 5, 275, 0.06735733442560111],
#  [9, 3, 7, 449, 0.05859140130007667],
#  [8, 3, 10, 234, 0.09188126560203755],
#  [7, 5, 8, 401, 0.08254128696627777],
#  [8, 4, 9, 224, 0.06710331620654518],
#  [6, 5, 6, 233, 0.05776303710577718],
#  [6, 2, 7, 470, 0.06562531218201478],
#  [8, 6, 5, 491, 0.07832342011214738],
#  [6, 3, 9, 379, 0.05781967026784073],
#  [9, 5, 9, 212, 0.05455412603505549]]

# %%
from skopt.plots import plot_objective, plot_evaluations

# %%
_ = plot_objective(best)

# %%
_ = plot_objective(ten)
