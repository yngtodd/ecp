# %%
from hyperspace.kepler import load_results
from hyperspace.kepler.plots import plot_convergence
from skopt.plots import plot_objective, plot_evaluations

import matplotlib
import matplotlib.pyplot as plt
plt.style.use(['seaborn-ticks'])

# %matplotlib inline

# %%
def objective():
    pass

# %%
theta = '/Users/youngtodd/ecp/theta/bench4096/results'
results = load_results(theta, sort=True)
best = results.pop(0)

# %%
matplotlib.rcParams['figure.figsize'] = [10, 10]

fig, _ = plot_convergence(best, results)

# %%
top250 = [results.pop(x) for x in range(250)]

# %%
matplotlib.rcParams['figure.figsize'] = [15, 15]

fig, _ = plot_convergence(best, top250)

# %%
_ = plot_objective(best)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-9-7ab09caf1584> in <module>()
# ----> 1 _ = plot_objective(best)
#
# ~/anaconda3/lib/python3.6/site-packages/scikit_optimize-0.5.2-py3.6.egg/skopt/plots.py in plot_objective(result, levels, n_points, n_samples, size, zscale, dimensions)
#     329         for j in range(space.n_dims):
#     330             if i == j:
# --> 331                 xi, yi = partial_dependence(space, result.models[-1], i,
#     332                                             j=None,
#     333                                             sample_points=rvs_transformed,
#
# IndexError: list index out of range
